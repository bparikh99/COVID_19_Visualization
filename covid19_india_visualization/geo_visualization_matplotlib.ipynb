# %% [markdown]
# # Visualization by geopandas

# %% [markdown]
# ### First import all necessary library

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Used shape file for visualization

# %%
map_data=gpd.read_file("C:/Users/himanshimehta/Downloads/Igismap/Indian_States.shp")

# %% [markdown]
# ### After getting dataframe  replace state_name

# %%
map_data['st_nm'] = map_data['st_nm'].str.replace('&', 'and')
map_data['st_nm'].replace('Arunanchal Pradesh', 'Arunachal Pradesh', inplace = True)
map_data['st_nm'].replace('Telangana', 'Telengana', inplace = True)
map_data['st_nm'].replace('NCT of Delhi', 'Delhi', inplace = True)
map_data['st_nm'].replace("Andaman and Nicobar Island",'Andaman and Nicobar Islands',inplace=True)

# %% [markdown]
# ### Get the data and clean it!!

# %%
dfs=pd.read_html("https://www.mohfw.gov.in/")
df=dfs[0]
df.columns
df.drop(columns=['S. No.'],inplace=True,axis=1)
df=df.rename(columns={'Name of State / UT':'st_nm',
       'Total Confirmed cases*':"confirmed",
       'Cured/Discharged/Migrated':"deasesed",
       'Deaths**':"deaths"})
df.drop(index=[33,34,35,36,37,38],inplace=True)

# %%
df
# Out:
#                           st_nm confirmed deasesed deaths
# 0   Andaman and Nicobar Islands        33       33      0
# 1                Andhra Pradesh      2407     1456     50
# 2             Arunachal Pradesh         1        1      0
# 3                         Assam       101       41      2
# 4                         Bihar      1262      475      8
# 5                    Chandigarh       191       51      3
# 6                  Chhattisgarh        86       59      0
# 7            Dadar Nagar Haveli         1        0      0
# 8                         Delhi     10054     4485    160
# 9                           Goa        29        7      0
# 10                      Gujarat     11379     4499    659
# 11                      Haryana       910      562     14
# 12             Himachal Pradesh        80       44      3
# 13            Jammu and Kashmir      1183      575     13
# 14                    Jharkhand       223      113      3
# 15                    Karnataka      1147      509     37
# 16                       Kerala       601      497      4
# 17                       Ladakh        43       24      0
# 18               Madhya Pradesh      4977     2403    248
# 19                  Maharashtra     33053     7688   1198
# 20                      Manipur         7        2      0
# 21                    Meghalaya        13       11      1
# 22                      Mizoram         1        1      0
# 23                       Odisha       828      220      4
# 24                   Puducherry        13        9      1
# 25                       Punjab      1964     1366     35
# 26                    Rajasthan      5202     2992    131
# 27                   Tamil Nadu     11224     4172     78
# 28                    Telengana      1551      992     34
# 29                      Tripura       167       85      0
# 30                  Uttarakhand        92       52      1
# 31                Uttar Pradesh      4259     2441    104
# 32                  West Bengal      2677      959    238

# %% [markdown]
# ### plot of map_data

# %%
map_data.plot()

# %% [markdown]
# ### Merged DataFrame

# %%
merged_data=pd.merge(map_data,df,how="left",on='st_nm')
merged_data
# Out:
#                           st_nm  \
# 0   Andaman and Nicobar Islands
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                    Chandigarh
# 5                  Chhattisgarh
# 6      Dadara and Nagar Havelli
# 7                 Daman and Diu
# 8                           Goa
# 9                       Gujarat
# 10                      Haryana
# 11             Himachal Pradesh
# 12            Jammu and Kashmir
# 13                    Jharkhand
# 14                    Karnataka
# 15                       Kerala
# 16                  Lakshadweep
# 17               Madhya Pradesh
# 18                  Maharashtra
# 19                      Manipur
# 20                    Meghalaya
# 21                      Mizoram
# 22                     Nagaland
# 23                        Delhi
# 24                   Puducherry
# 25                       Punjab
# 26                    Rajasthan
# 27                       Sikkim
# 28                   Tamil Nadu
# 29                    Telengana
# 30                      Tripura
# 31                Uttar Pradesh
# 32                  Uttarakhand
# 33                  West Bengal
# 34                       Odisha
# 35               Andhra Pradesh
#
#                                              geometry confirmed deasesed  \
# 0   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...        33       33
# 1   POLYGON ((96.16261 29.38078, 96.16860 29.37432...         1        1
# 2   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...       101       41
# 3   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...      1262      475
# 4   POLYGON ((76.84147 30.75996, 76.83599 30.73623...       191       51
# 5   POLYGON ((83.33532 24.09885, 83.35346 24.09627...        86       59
# 6   POLYGON ((73.20657 20.12216, 73.20797 20.10650...       NaN      NaN
# 7   MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...       NaN      NaN
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...        29        7
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...     11379     4499
# 10  POLYGON ((76.85065 30.87512, 76.86594 30.86691...       910      562
# 11  POLYGON ((76.79634 33.25490, 76.80351 33.25275...        80       44
# 12  POLYGON ((74.73451 37.02068, 74.73647 37.01937...      1183      575
# 13  POLYGON ((87.60582 25.31512, 87.61279 25.31184...       223      113
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...      1147      509
# 15  POLYGON ((74.99575 12.79227, 75.00006 12.78777...       601      497
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...       NaN      NaN
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...      4977     2403
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...     33053     7688
# 19  POLYGON ((94.57602 25.64221, 94.57487 25.63858...         7        2
# 20  POLYGON ((91.85632 26.10353, 91.86717 26.09906...        13       11
# 21  POLYGON ((92.80022 24.41630, 92.80310 24.41603...         1        1
# 22  POLYGON ((95.21458 26.93095, 95.21719 26.92818...       NaN      NaN
# 23  POLYGON ((77.09361 28.86940, 77.10973 28.86722...     10054     4485
# 24  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...        13        9
# 25  POLYGON ((75.88469 32.48841, 75.90303 32.47169...      1964     1366
# 26  POLYGON ((73.89849 29.97896, 73.90021 29.97140...      5202     2992
# 27  POLYGON ((88.65381 28.09883, 88.66265 28.08956...       NaN      NaN
# 28  MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...     11224     4172
# 29  POLYGON ((81.05614 17.79097, 81.05834 17.75464...      1551      992
# 30  POLYGON ((92.22108 24.50131, 92.22771 24.49862...       167       85
# 31  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...      4259     2441
# 32  POLYGON ((79.21047 31.34846, 79.21386 31.34680...        92       52
# 33  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...      2677      959
# 34  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...       828      220
# 35  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...      2407     1456
#
#    deaths
# 0       0
# 1       0
# 2       2
# 3       8
# 4       3
# 5       0
# 6     NaN
# 7     NaN
# 8       0
# 9     659
# 10     14
# 11      3
# 12     13
# 13      3
# 14     37
# 15      4
# 16    NaN
# 17    248
# 18   1198
# 19      0
# 20      1
# 21      0
# 22    NaN
# 23    160
# 24      1
# 25     35
# 26    131
# 27    NaN
# 28     78
# 29     34
# 30      0
# 31    104
# 32      1
# 33    238
# 34      4
# 35     50

# %% [markdown]
# ### Visualization Part

# %%
merged_data['coords'] = merged_data['geometry'].apply(lambda x: x.representative_point().coords[:])
merged_data['coords'] = [coords[0] for coords in merged_data['coords']]

# %%
merged_data
# Out:
#                           st_nm  \
# 0   Andaman and Nicobar Islands
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                    Chandigarh
# 5                  Chhattisgarh
# 6      Dadara and Nagar Havelli
# 7                 Daman and Diu
# 8                           Goa
# 9                       Gujarat
# 10                      Haryana
# 11             Himachal Pradesh
# 12            Jammu and Kashmir
# 13                    Jharkhand
# 14                    Karnataka
# 15                       Kerala
# 16                  Lakshadweep
# 17               Madhya Pradesh
# 18                  Maharashtra
# 19                      Manipur
# 20                    Meghalaya
# 21                      Mizoram
# 22                     Nagaland
# 23                        Delhi
# 24                   Puducherry
# 25                       Punjab
# 26                    Rajasthan
# 27                       Sikkim
# 28                   Tamil Nadu
# 29                    Telengana
# 30                      Tripura
# 31                Uttar Pradesh
# 32                  Uttarakhand
# 33                  West Bengal
# 34                       Odisha
# 35               Andhra Pradesh
#
#                                              geometry  confirmed deasesed  \
# 0   MULTIPOLYGON (((93.71976 7.20707, 93.71909 7.2...         33       33
# 1   POLYGON ((96.16261 29.38078, 96.16860 29.37432...          1        1
# 2   MULTIPOLYGON (((89.74323 26.30362, 89.74290 26...        101       41
# 3   MULTIPOLYGON (((84.50720 24.26323, 84.50355 24...       1262      475
# 4   POLYGON ((76.84147 30.75996, 76.83599 30.73623...        191       51
# 5   POLYGON ((83.33532 24.09885, 83.35346 24.09627...         86       59
# 6   POLYGON ((73.20657 20.12216, 73.20797 20.10650...          0        0
# 7   MULTIPOLYGON (((72.89335 20.44539, 72.89281 20...          0        0
# 8   MULTIPOLYGON (((74.11918 14.75344, 74.11350 14...         29        7
# 9   MULTIPOLYGON (((71.70375 20.99958, 71.70375 20...      11379     4499
# 10  POLYGON ((76.85065 30.87512, 76.86594 30.86691...        910      562
# 11  POLYGON ((76.79634 33.25490, 76.80351 33.25275...         80       44
# 12  POLYGON ((74.73451 37.02068, 74.73647 37.01937...       1183      575
# 13  POLYGON ((87.60582 25.31512, 87.61279 25.31184...        223      113
# 14  MULTIPOLYGON (((74.69694 13.32782, 74.69562 13...       1147      509
# 15  POLYGON ((74.99575 12.79227, 75.00006 12.78777...        601      497
# 16  MULTIPOLYGON (((74.10131 11.20431, 74.09908 11...          0        0
# 17  MULTIPOLYGON (((74.17932 22.39059, 74.17776 22...       4977     2403
# 18  MULTIPOLYGON (((73.46270 16.03710, 73.46178 16...      33053     7688
# 19  POLYGON ((94.57602 25.64221, 94.57487 25.63858...          7        2
# 20  POLYGON ((91.85632 26.10353, 91.86717 26.09906...         13       11
# 21  POLYGON ((92.80022 24.41630, 92.80310 24.41603...          1        1
# 22  POLYGON ((95.21458 26.93095, 95.21719 26.92818...          0        0
# 23  POLYGON ((77.09361 28.86940, 77.10973 28.86722...      10054     4485
# 24  MULTIPOLYGON (((79.76528 10.99681, 79.76963 10...         13        9
# 25  POLYGON ((75.88469 32.48841, 75.90303 32.47169...       1964     1366
# 26  POLYGON ((73.89849 29.97896, 73.90021 29.97140...       5202     2992
# 27  POLYGON ((88.65381 28.09883, 88.66265 28.08956...          0        0
# 28  MULTIPOLYGON (((78.19188 8.72730, 78.18996 8.7...      11224     4172
# 29  POLYGON ((81.05614 17.79097, 81.05834 17.75464...       1551      992
# 30  POLYGON ((92.22108 24.50131, 92.22771 24.49862...        167       85
# 31  MULTIPOLYGON (((80.44802 24.99631, 80.44080 24...       4259     2441
# 32  POLYGON ((79.21047 31.34846, 79.21386 31.34680...         92       52
# 33  MULTIPOLYGON (((88.01861 21.57278, 88.01889 21...       2677      959
# 34  MULTIPOLYGON (((86.38937 19.96351, 86.38840 19...        828      220
# 35  MULTIPOLYGON (((81.10380 17.82269, 81.10610 17...       2407     1456
#
#    deaths                                   coords
# 0       0  (92.83153129257889, 12.611584970470062)
# 1       0  (95.03199805598612, 28.055114856615404)
# 2       2  (90.76265036100918, 26.052225148671738)
# 3       8  (86.12533485112044, 25.902658098342613)
# 4       3  (76.78051175496091, 30.730184003289168)
# 5       0   (81.50899708552288, 20.94914121899211)
# 6       0  (73.00811326266309, 20.206507820529538)
# 7       0   (70.93083380880213, 20.71944808935791)
# 8       0  (74.10419744395932, 15.347738516669267)
# 9     659  (71.98745611099406, 22.414733888807973)
# 10     14   (76.24271266597503, 29.28848799387586)
# 11      3  (77.35024360355877, 31.817465026989453)
# 12     13   (76.75588492772906, 34.67851205408809)
# 13      3  (85.16891460620934, 23.660009572234003)
# 14     37  (75.53284791304281, 15.019953487363608)
# 15      4  (76.44497705340197, 10.544036269658164)
# 16      0    (74.04345883424992, 11.2771894683693)
# 17    248  (79.39415128834862, 23.972803328410947)
# 18   1198   (75.36374751055095, 18.81792358895251)
# 19      0  (93.86754182803656, 24.762889638096368)
# 20      1  (91.26804922304613, 25.573591710489097)
# 21      0  (92.87146997475472, 23.232613513852613)
# 22      0  (94.55764474490528, 26.116901452140354)
# 23    160  (77.12909320274471, 28.640197681028212)
# 24      1  (79.79832556750961, 10.915108898506901)
# 25     35  (75.65192454447362, 31.060734839091594)
# 26    131   (73.82645251596583, 26.63095751207956)
# 27      0  (88.46160019987005, 27.605484115999218)
# 28     78  (78.34938871022862, 10.820942218958294)
# 29     34   (79.30527136633987, 17.87444984233639)
# 30      0   (91.65890517182791, 23.73541954962255)
# 31    104    (80.7823825009929, 27.14064170764874)
# 32      1  (79.31955002279173, 30.088392570610694)
# 33    238  (88.05685058142063, 24.411467840318636)
# 34      4   (84.48131199348137, 20.18790593171343)
# 35     50  (79.61537165157097, 15.893833407885495)

# %%
merged_data.fillna(0, inplace = True)
merged_data['confirmed']=merged_data['confirmed'].astype(int)
bbox_props = dict(boxstyle="round", fc="w", ec="gray", alpha=0.8,lw=1)
print(bbox_props)
# create figure and axes for Matplotlib and set the title

fig, ax = plt.subplots(1, figsize=(20, 12))
for idx, row in merged_data.iterrows():
    ax.annotate(s=row['st_nm']+'\n'+'cases'+" "+str(int(row['confirmed'])), xy=row['coords'], color='black',
                 horizontalalignment='center', bbox=bbox_props, fontsize=9)
ax.axis('off')
ax.set_title('Covid-19 Statewise Data - Confirmed Cases', fontdict = {'fontsize': '25', 'fontweight' : '3'})
# plot the figure
merged_data.plot(column = 'confirmed', cmap='Reds', linewidth=0.8, ax=ax, edgecolor='0.8', legend = True)
plt.show()
plt.savefig("Indiancases.jpeg")
# Out:
# {'boxstyle': 'round', 'fc': 'w', 'ec': 'gray', 'alpha': 0.8, 'lw': 1}
